# %% [markdown]
# ### 풀이 영상: https://youtu.be/QpNufh_ZV7A?t=133

# %% [markdown]
# # Q. 결측치 데이터(행)을 제거하고, 앞에서부터 60% 데이터만 활용해, 'f1' 컬럼 3사분위 값을 구하시오
# - 60%가 소수점일 경우 절사(예: 36.6 일때 36으로 계산)
# - data: t1-data1.csv

# %%
import pandas as pd
df = pd.read_csv("../input/big-data-analytics-certification/t1-data1.csv")
df.head(2)
# Out:
#      id  age city    f1  f2    f4         f5
# 0  id01  2.0   서울   NaN   0  ENFJ  91.297791
# 1  id02  9.0   서울  70.0   1  ENFJ  60.339826

# %% [markdown]
# # Your Code

# %%
df.isnull().sum()
# Out:
# id       0
# age      0
# city     0
# f1      29
# f2       0
# f4       0
# f5       0
# dtype: int64

# %%
# 결측치 행 제거
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id      0
# age     0
# city    0
# f1      0
# f2      0
# f4      0
# f5      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 1 to 88
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      61 non-null     object
#  1   age     61 non-null     float64
#  2   city    61 non-null     object
#  3   f1      61 non-null     float64
#  4   f2      61 non-null     int64
#  5   f4      61 non-null     object
#  6   f5      61 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
# 앞에서부터 60% -> f1의 3사분위값
df['f1'].iloc[:int(len(df)*0.6)].quantile(0.75)
# Out:
# 77.25

# %% [markdown]
# # solution

# %%
df = pd.read_csv("../input/big-data-analytics-certification/t1-data1.csv")
df = df.dropna()
df = df.iloc[:int(len(df)*0.6)]
print(df['f1'].quantile(.75))
# Out:
# 77.25
