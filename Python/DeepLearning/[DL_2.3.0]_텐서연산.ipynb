# %% [markdown]
# ## 2.3.1 원소별 연산

# %%
# relu 연산
def naive_relu(x):
    assert len(x.shape) == 2     # x는 랭크-2 numpy 배열이다.
    x = x.copy()    # 입력 텐서 자체를 바꾸지 않고 복사한다.
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

def naive_add(x, y):
    assert len(x.shape) == 2     # x와 y는 랭크-2 numpy 배열이다.
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %% [markdown]
# - 넘파이는 다음과 같은 원소별 연산을 엄청난 속도로 처리한다.
#     - z = x + y
#     - z = np.maximum(x, 0.)

# %%
import numpy as np
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()

for _ in range(1000):
    z = x + y   # 원소별 덧셈
    z = np.maximum(x, 0.)   # 원소별 relu함수
print("걸린 시간: {0:.2f} s".format(time.time() - t0))
# Out:
# 걸린 시간: 0.01 s

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("걸린 시간: {0:.2f} s".format(time.time() - t0))
# Out:
# 걸린 시간: 1.88 s

# %% [markdown]
# ## 2.3.2 브로드캐스팅
# - https://numpy.org/doc/stable/user/basics.broadcasting.html

# %%
import numpy as np
X = np.random.random((32, 10))  # 크기가 (32, 10)인 랜덤한 행렬
y = np.random.random((10,))  # 크기가 (10,)인 랜덤한 행렬

# %%
y = np.expand_dims(y, axis=0)   # y의 크기는 (1, 10)
Y = np.concatenate([y] * 32, axis = 0)  # 축 0(행)을 따라 32번 반복 => (32, 10)이 됨

# %%
X+Y
# Out:
# array([[1.42605891, 1.75958601, 0.22955023, 1.28992232, 1.26710511,
#         1.27350761, 1.51828205, 0.45131644, 1.40959488, 1.24468109],
#        [1.49726246, 1.69223063, 0.72761234, 0.8880135 , 0.99957371,
#         0.69751699, 0.81654869, 0.39498451, 1.17225092, 1.1816659 ],
#        [0.94906471, 1.01544566, 1.05797533, 1.20223005, 0.6124968 ,
#         1.20594446, 1.36353713, 0.40309306, 1.74641453, 0.83561549],
#        [1.24282125, 1.57078294, 0.1244762 , 0.81458703, 0.97837627,
#         0.91123097, 0.97770359, 0.96828204, 0.98719718, 0.90769705],
#        [1.07926692, 1.83101566, 0.92276879, 1.27553495, 1.39852479,
#         0.92993879, 0.95436069, 0.26534566, 1.8107677 , 0.52858115],
#        [1.53593385, 1.70396399, 0.92856855, 0.80799966, 0.96576913,
#         0.93699004, 1.11079204, 0.4993366 , 1.8426821 , 0.56482864],
#        [0.67045186, 1.94217943, 0.50969127, 1.16403195, 1.10332527,
#         0.71021806, 1.08715998, 1.01135154, 1.61514744, 0.67857378],
#        [0.76974192, 1.13037684, 0.82422397, 1.27750111, 0.91718562,
#         1.31376139, 1.0460187 , 0.7318683 , 1.57633446, 0.78570267],
#        [1.30920657, 1.36848356, 0.19646202, 1.32317458, 0.90826999,
#         0.59136023, 1.47861928, 1.23133176, 1.33570598, 0.5263811 ],
#        [0.90089617, 1.01052322, 0.64201031, 1.44174196, 1.47525863,
#         0.61552421, 1.09144312, 1.11707222, 1.42558867, 0.96828918],
#        [1.51414765, 1.6282594 , 0.68046621, 0.95372436, 1.51760017,
#         0.52670837, 0.8447997 , 0.45491825, 1.73272462, 0.44734325],
#        [1.11343105, 1.90649526, 0.40195396, 0.64840072, 0.75176165,
#         1.089953  , 1.62417807, 0.44695682, 1.36666351, 1.10805232],
#        [0.99118537, 1.49271096, 0.17761493, 1.01808408, 1.32114557,
#         1.17081788, 0.8337368 , 1.04479054, 1.6502687 , 1.01199106],
#        [1.510252  , 1.50177652, 0.40552867, 0.72681368, 0.89373548,
#         0.85993727, 1.58622968, 0.76105771, 1.09031755, 0.93632253],
#        [0.70950411, 1.3346468 , 0.1729617 , 1.33935495, 0.71468907,
#         0.57006521, 1.14151653, 0.6824677 , 1.29858649, 1.25761294],
#        [1.01477171, 1.52085139, 1.03237724, 1.18745879, 1.41482378,
#         0.93478661, 0.718981  , 0.53094895, 0.97094706, 0.55673458],
#        [0.67692331, 1.60915652, 0.42015787, 0.6799464 , 0.92397417,
#         0.91803194, 1.27040836, 0.6562701 , 1.18544287, 0.567617  ],
#        [0.90583735, 1.3384282 , 0.9094582 , 0.99837817, 0.61565347,
#         0.86805303, 1.48250205, 0.36305052, 1.16989903, 0.78747765],
#        [1.3087677 , 1.03935401, 0.20245406, 1.4132877 , 1.18674049,
#         0.66923182, 1.30813839, 0.69955147, 1.93528511, 0.95239104],
#        [0.90427455, 1.37530454, 0.86409513, 1.3925952 , 0.71203608,
#         0.5668903 , 1.127862  , 1.04893083, 1.05522249, 0.84041216],
#        [0.81506573, 1.51599846, 1.07158082, 1.42241885, 0.79805899,
#         0.70002877, 0.73218684, 0.83679366, 1.04628964, 0.89671768],
#        [0.83110246, 1.68997864, 0.99039818, 0.87322907, 0.84832107,
#         0.72453162, 0.87205523, 0.775881  , 1.52752183, 0.88378745],
#        [1.65633564, 1.42198896, 0.87153158, 1.16948351, 1.54267027,
#         1.10988851, 1.40853997, 0.51034483, 1.02570427, 0.67944811],
#        [0.84407512, 1.63533161, 0.59013109, 1.05398563, 1.02880155,
#         1.14720001, 1.28171596, 0.87993193, 1.8773982 , 0.990277  ],
#        [0.76828695, 1.48696165, 0.77292987, 0.89838704, 0.78427467,
#         1.30578276, 0.78981324, 0.77860921, 1.04203222, 1.09758048],
#        [0.80015113, 1.01628832, 0.51110374, 0.77678219, 1.30266351,
#         0.88734776, 1.07287033, 0.4570558 , 0.98552616, 0.6525987 ],
#        [1.34057228, 1.18575759, 0.41096027, 0.89986045, 1.16337116,
#         0.77734386, 1.20333014, 0.63873263, 1.87072344, 0.84557268],
#        [1.34324965, 1.19211357, 0.40194071, 1.39045155, 1.15481812,
#         0.50079143, 1.33273319, 1.20400488, 1.70666178, 0.64915633],
#        [1.49051903, 1.87773508, 0.20434389, 1.55973943, 0.76613537,
#         0.70087507, 1.57218479, 0.89268978, 1.57619365, 0.95268522],
#        [1.19202041, 1.26183164, 0.65389551, 0.72727309, 1.58365255,
#         1.12675266, 1.32266287, 0.80706623, 1.04587222, 0.91652285],
#        [1.29901151, 1.54093914, 1.08352892, 1.22356566, 0.79238668,
#         1.16329226, 0.84881419, 1.19903533, 0.99966169, 1.1463854 ],
#        [0.8679628 , 1.33228173, 0.33898867, 1.01137925, 0.85627147,
#         0.71915376, 1.50239939, 0.45925858, 1.34785775, 1.13789136]])

# %% [markdown]
# - 단순하게 구현

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %% [markdown]
# - 크기가 다른 두 텐서에 브로드캐스팅을 원소별 maximum 연산을 적용하는 예

# %%
import numpy as np

x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)    # 출력z크기는 x와 동일하게 (64, 3, 32, 10)입니다.
z.shape
# Out:
# (64, 3, 32, 10)
